# %%
import os
import pandas as pd
from io import StringIO
import matplotlib.pyplot as plt

with open('data_1.txt', 'r') as f:
    data_string = f.read()

df = pd.read_csv(StringIO(data_string), sep='\t')
df
# Out:
#                         time                     DeviceName  AccX(g)  AccY(g)  \
# 0    2024-10-20 13:42:13:407  WT901BLE68(D1:B7:24:41:63:E6)    0.011   -0.014
# 1    2024-10-20 13:42:13:519  WT901BLE68(D1:B7:24:41:63:E6)   -0.070   -0.015
# 2    2024-10-20 13:42:13:609  WT901BLE68(D1:B7:24:41:63:E6)   -0.035   -0.198
# 3    2024-10-20 13:42:13:721  WT901BLE68(D1:B7:24:41:63:E6)    0.067   -0.026
# 4    2024-10-20 13:42:13:812  WT901BLE68(D1:B7:24:41:63:E6)   -0.125   -0.046
# ..                       ...                            ...      ...      ...
# 193  2024-10-20 13:42:32:859  WT901BLE68(D1:B7:24:41:63:E6)   -0.673   -0.513
# 194  2024-10-20 13:42:32:941  WT901BLE68(D1:B7:24:41:63:E6)   -0.465   -0.362
# 195   2024-10-20 13:42:33:67  WT901BLE68(D1:B7:24:41:63:E6)   -0.591   -0.436
# 196  2024-10-20 13:42:33:143  WT901BLE68(D1:B7:24:41:63:E6)   -0.526   -0.643
# 197  2024-10-20 13:42:33:260  WT901BLE68(D1:B7:24:41:63:E6)   -0.504   -0.679
#
#      AccZ(g)  AsX(°/s)  AsY(°/s)  AsZ(°/s)  AngleX(°)  AngleY(°)  ...  HX(uT)  \
# 0      1.014     0.000     0.000     0.000      -0.81      -0.74  ... -49.098
# 1      1.013     0.366     0.793    78.552      -0.62      -0.70  ... -49.098
# 2      1.013     2.869    -0.732   -24.292      -0.76      -0.70  ... -49.098
# 3      1.016   -11.719    -0.793    19.897      -0.80      -0.67  ... -49.098
# 4      1.026     4.456     5.920     5.066      -0.55      -0.44  ... -48.804
# ..       ...       ...       ...       ...        ...        ...  ...     ...
# 193   -0.670    22.583   -47.180   135.315    -151.81      44.82  ... -56.644
# 194   -0.553    74.890    31.372    14.221    -151.97      47.95  ... -56.644
# 195   -0.494    38.513   -49.866   -57.068    -143.59      46.88  ... -56.644
# 196   -0.584    23.987     7.751   -31.189    -134.51      43.74  ... -54.978
# 197   -0.541   -14.099    -7.568   -51.025    -131.78      39.89  ... -54.978
#
#      HY(uT)   HZ(uT)     Q0()     Q1()     Q2()     Q3()  Temperature(°C)  \
# 0    32.830 -125.244  0.99435 -0.00778 -0.00571 -0.10532             26.3
# 1    32.830 -125.244  0.99435 -0.00778 -0.00571 -0.10532             26.3
# 2    32.830 -125.244  0.99765 -0.00531 -0.00552 -0.06760             26.3
# 3    32.830 -125.244  0.99765 -0.00531 -0.00552 -0.06760             26.3
# 4    29.302 -126.812  0.99765 -0.00531 -0.00552 -0.06760             26.3
# ..      ...      ...      ...      ...      ...      ...              ...
# 193  31.066  -33.026  0.06052 -0.82660 -0.45651  0.32336             26.7
# 194  31.066  -33.026 -0.00763 -0.80545 -0.38062  0.45410             26.7
# 195  31.066  -33.026 -0.00763 -0.80545 -0.38062  0.45410             26.7
# 196  41.160  -37.240 -0.00763 -0.80545 -0.38062  0.45410             26.7
# 197  41.160  -37.240 -0.00763 -0.80545 -0.38062  0.45410             26.7
#
#      Version()  Battery level(%)
# 0        13111               100
# 1        13111               100
# 2        13111               100
# 3        13111               100
# 4        13111               100
# ..         ...               ...
# 193      13111               100
# 194      13111               100
# 195      13111               100
# 196      13111               100
# 197      13111               100
#
# [198 rows x 21 columns]

# %%
def plot_sensor_data(df):
    # Convert time to numeric index (0,1,2,...)
    x = range(len(df))
    
    plt.figure(figsize=(10, 6))
    plt.plot(x, df['AccX(g)'], label='AccX')
    plt.plot(x, df['AccY(g)'], label='AccY')
    plt.plot(x, df['AccZ(g)'], label='AccZ')
    plt.xlabel('Time Step')
    plt.ylabel('Value')
    plt.legend()
    plt.grid(True)
    plt.show()

plot_sensor_data(df)
print(max(df['AccX(g)']))
# Out:
# 1.006
